# %% [markdown]
# # 1- Problem Statement

# %% [markdown]
# #### - You own an ice cream business and you want to create a model to predict daily revenue in dollars based on temperature (degC).
# #### - You decided to build a simple Artificial Neural Network to solve this Problem.
# #### - Data set:
# 	- Input (X): Outside Air Temperature
# 	- Output (y): Overall daily revenue generated in Dollars
# #### - This is A Regression Example

# %% [markdown]
# # 0- IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1- IMPORT DATASET

# %%
sales_df = pd.read_csv('018 SalesData.csv')

# %%
sales_df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
sales_df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
sales_df.tail()
# Out:
#      Temperature     Revenue
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
sales_df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
sales_df.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %% [markdown]
# # 2- VISUALIZE DATASET

# %%
sns.scatterplot(sales_df['Temperature'], sales_df['Revenue'])

# %% [markdown]
# # 3- CREATE TESTING AND TRAINING DATASET

# %%
X_train = sales_df['Temperature']
y_train = sales_df['Revenue']

# %% [markdown]
# # 4- BUILD AND TRAIN THE MODEL

# %%
X_train.shape
# Out:
# (500,)

# %%
y_train.shape
# Out:
# (500,)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
model = Sequential()
model.add(Dense(units = 1, input_shape = [1]))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(0.1), loss = 'mean_squared_error' )

# %%
epochs = model.fit(X_train, y_train, epochs = 1000)
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 0s 409us/step - loss: 320223.1182
# Epoch 2/1000
# 500/500 [==============================] - 0s 60us/step - loss: 278075.7493
# Epoch 3/1000
# 500/500 [==============================] - 0s 62us/step - loss: 239390.9958
# Epoch 4/1000
# 500/500 [==============================] - 0s 66us/step - loss: 205283.0301
# Epoch 5/1000
# 500/500 [==============================] - 0s 72us/step - loss: 174616.7480
# Epoch 6/1000
# 500/500 [==============================] - 0s 74us/step - loss: 147897.3039
# Epoch 7/1000
# 500/500 [==============================] - 0s 66us/step - loss: 124428.1045
# Epoch 8/1000
# 500/500 [==============================] - 0s 74us/step - loss: 103998.1166
# Epoch 9/1000
# 500/500 [==============================] - 0s 70us/step - loss: 86336.8100
# Epoch 10/1000
# 500/500 [==============================] - 0s 94us/step - loss: 71050.5049
# Epoch 11/1000
# ...

# %% [markdown]
# # 5- EVALUATE THE MODEL

# %%
epochs.history.keys()
# Out:
# dict_keys(['loss'])

# %%
plt.plot(epochs.history['loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend(['Training Loss'])

# %%
model.get_weights()
# Out:
# [array([[21.513502]], dtype=float32), array([44.847355], dtype=float32)]

# %%
# test the model
TEMP = 5
revenue = model.predict([TEMP])
print('Revenue Prediction Using Trained ANN =', revenue)
# Out:
# Revenue Prediction Using Trained ANN = [[152.41487]]

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, model.predict(X_train), color = 'red')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated vs. Temerature @Ice Cream Stand')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temerature @Ice Cream Stand')

# %% [markdown]
# # 6- CONFIRM USING REGRESSION KIT IN SCIKIT LEARN

# %%
X_train = X_train.values.reshape(-1, 1)

# %%
X_train.shape
# Out:
# (500, 1)

# %%
y_train = y_train.values.reshape(-1, 1)

# %%
y_train.shape
# Out:
# (500, 1)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Linear Model Coeff(m)', regressor.coef_)
print('Linear Model Coeff(b)', regressor.intercept_)
# Out:
# Linear Model Coeff(m) [[21.44362551]]
# Linear Model Coeff(b) [44.83126709]

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated vs. Temerature @Ice Cream Stand')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temerature @Ice Cream Stand')
